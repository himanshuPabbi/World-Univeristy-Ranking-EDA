# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cwurData.csv")

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df.tail()
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
df.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')

# %%
sns.distplot(df['broad_impact'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='broad_impact', ylabel='Density'>

# %%
mean_val=df['broad_impact'].mean()

# %%
mean_val
# Out:
# 496.6995

# %%
df['broad_impact'].fillna(mean_val,inplace=True)

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
sns.boxplot(df['world_rank'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='world_rank'>

# %%
sns.boxplot(df['national_rank'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='national_rank'>

# %%
q1=df['national_rank'].quantile(0.25)

# %%
q3=df['national_rank'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['national_rank']>lower) & (df['national_rank']<upper)]

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
sns.boxplot(df['alumni_employment'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alumni_employment'>

# %%
sns.boxplot(df['publications'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='publications'>

# %%
sns.boxplot(df['influence'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='influence'>

# %%
sns.boxplot(df['citations'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='citations'>

# %%
sns.boxplot(df['patents'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='patents'>

# %%
sns.boxplot(df['score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='score'>

# %%
q1=df['score'].quantile(0.25)

# %%
q3=df['score'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['score']>lower) & (df['score']<upper)]

# %%
df
# Out:
#       world_rank                                  institution   country  \
# 35            36  University of North Carolina at Chapel Hill       USA
# 36            37           Washington University in St. Louis       USA
# 37            38                           University of Utah       USA
# 38            39           University of Washington - Seattle       USA
# 39            40      University of California, Santa Barbara       USA
# ...          ...                                          ...       ...
# 2195         996                    University of the Algarve  Portugal
# 2196         997                        Alexandria University     Egypt
# 2197         998                  Federal University of Ceará    Brazil
# 2198         999                       University of A Coruña     Spain
# 2199        1000              China Pharmaceutical University     China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
sns.boxplot(df['broad_impact'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='broad_impact'>

# %%
sns.boxplot(df['quality_of_education'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality_of_education'>

# %%
q1=df['quality_of_education'].quantile(0.25)

# %%
q3=df['quality_of_education'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['quality_of_education']>lower) & (df['quality_of_education']<upper)]

# %%
df
# Out:
#       world_rank                                  institution   country  \
# 35            36  University of North Carolina at Chapel Hill       USA
# 36            37           Washington University in St. Louis       USA
# 37            38                           University of Utah       USA
# 38            39           University of Washington - Seattle       USA
# 39            40      University of California, Santa Barbara       USA
# ...          ...                                          ...       ...
# 2195         996                    University of the Algarve  Portugal
# 2196         997                        Alexandria University     Egypt
# 2197         998                  Federal University of Ceará    Brazil
# 2198         999                       University of A Coruña     Spain
# 2199        1000              China Pharmaceutical University     China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
sns.boxplot(df['quality_of_faculty'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality_of_faculty'>

# %%
q1=df['quality_of_faculty'].quantile(0.25)

# %%
q3=df['quality_of_faculty'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['quality_of_faculty']>lower) & (df['quality_of_faculty']<upper)]

# %%
sns.boxplot(df['quality_of_faculty'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality_of_faculty'>

# %%
sns.boxplot(df['year'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year'>

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %% [markdown]
# # Comparing institution in USA based on world ranking and National Raking

# %%
USA_df=df[df['country']=="USA"]

# %%
USA_df=USA_df.reset_index(drop=True)

# %%
new_df=USA_df[['world_rank','institution','national_rank']]

# %%
new_df=new_df.sort_values(by="world_rank").reset_index(drop=True)

# %%
new_df
# Out:
#     world_rank                         institution  national_rank
# 0           78                    Emory University             49
# 1           80     Georgia Institute of Technology             48
# 2           83     Georgia Institute of Technology             52
# 3          112           Michigan State University             59
# 4          113               Georgetown University             59
# ..         ...                                 ...            ...
# 75         275             Northeastern University            108
# 76         282    Rensselaer Polytechnic Institute            110
# 77         291  University of Texas at San Antonio            112
# 78         293        Medical College of Wisconsin            113
# 79         297        Medical College of Wisconsin            113
#
# [80 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['institution'],y=new_df['world_rank'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df=new_df.sort_values(by="national_rank").reset_index(drop=True)

# %%
new_df
# Out:
#     world_rank                                        institution  \
# 0           80                    Georgia Institute of Technology
# 1           78                                   Emory University
# 2           83                    Georgia Institute of Technology
# 3          112                          Michigan State University
# 4          113                              Georgetown University
# ..         ...                                                ...
# 75         268  University at Buffalo, The State University of...
# 76         271  Virginia Polytechnic Institute and State Unive...
# 77         291                 University of Texas at San Antonio
# 78         293                       Medical College of Wisconsin
# 79         297                       Medical College of Wisconsin
#
#     national_rank
# 0              48
# 1              49
# 2              52
# 3              59
# 4              59
# ..            ...
# 75            110
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['institution'],y=new_df['national_rank'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Comparing institution in USA based on different features

# %%
USA_df
# Out:
#     world_rank                                        institution country  \
# 0           78                                   Emory University     USA
# 1           83                    Georgia Institute of Technology     USA
# 2          112                          Michigan State University     USA
# 3          118                              Georgetown University     USA
# 4          121                         Baylor College of Medicine     USA
# ..         ...                                                ...     ...
# 75         273  University at Buffalo, The State University of...     USA
# 76         275                            Northeastern University     USA
# 77         282                   Rensselaer Polytechnic Institute     USA
# 78         291                 University of Texas at San Antonio     USA
# 79         297                       Medical College of Wisconsin     USA
#
#     national_rank  quality_of_education  alumni_employment  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['quality_of_education'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['publications'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['patents'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['alumni_employment'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['score'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(x=USA_df['publications'])
# Out:
# <AxesSubplot:xlabel='publications', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['broad_impact'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=USA_df['institution'],y=USA_df['citations'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %% [markdown]
# # Comparing Top 10 instituion Based on alumni_employment

# %%
alumni_employment_df=df[['institution','alumni_employment']]

# %%
top_10_alumni_employment_df=alumni_employment_df.sort_values(by="alumni_employment",ascending=False)[:10]

# %%
top_10_alumni_employment_df=top_10_alumni_employment_df.reset_index(drop=True)

# %%
top_10_alumni_employment_df
# Out:
#                                     institution  alumni_employment
# 0               China Pharmaceutical University                567
# 1                   Soochow University (Suzhou)                567
# 2              University of the Basque Country                567
# 3              Technical University of Dortmund                567
# 4                        University of Konstanz                567
# 5                           University of Seoul                567
# 6                       University of Newcastle                567
# 7                          University of Angers                567
# 8  Martin Luther University of Halle-Wittenberg                567
# 9              Huazhong Agricultural University                567

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_10_alumni_employment_df['institution'],y=top_10_alumni_employment_df['alumni_employment'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Comparing Top 10 Country instituions Based on national_rank and world rank

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %%
top_10_country_df=df[['country','institution','world_rank','national_rank','quality_of_faculty','score','quality_of_education']]

# %%
top_10_country_df=top_10_country_df.reset_index(drop=True)

# %%
top_10_country_df.sort_values(by="national_rank")
# Out:
#          country                                        institution  \
# 658  Puerto Rico              University of Puerto Rico at Mayagüez
# 809     Thailand                           Chulalongkorn University
# 222        Chile            Pontifical Catholic University of Chile
# 825       Mexico           National Autonomous University of Mexico
# 830        India               Indian Institute of Technology Delhi
# ..           ...                                                ...
# 786          USA                   Rensselaer Polytechnic Institute
# 96           USA  Virginia Polytechnic Institute and State Unive...
# 794          USA                 University of Texas at San Antonio
# 799          USA                       Medical College of Wisconsin
# 113          USA                       Medical College of Wisconsin
#
#      world_rank  national_rank  quality_of_faculty  score  \
# 658         977              1                 210  44.29
# ...

# %%
top_10_country_df.sort_values(by="world_rank")
# Out:
#       country                                institution  world_rank  \
# 682     Japan                          Tohoku University          73
# 0         USA                           Emory University          78
# 683     China                        Tsinghua University          78
# 684       USA            Georgia Institute of Technology          80
# 685   Belgium             Katholieke Universiteit Leuven          82
# ...       ...                                        ...         ...
# 679     China                  Shaanxi Normal University         998
# 1362    Spain                     University of A Coruña         999
# 680     China  National University of Defense Technology         999
# 681     China                         Yanbian University        1000
# 1363    China            China Pharmaceutical University        1000
#
#       national_rank  quality_of_faculty  score  quality_of_education
# 682               6                 218  52.57                    41
# ...

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %% [markdown]
# # Comparing Top 20 Country and instituions Based on publications

# %%
top_20_country_df=df[['country','institution','publications']]

# %%
top_20_country_df=top_20_country_df.reset_index(drop=True)

# %%
top_20_country_df=top_20_country_df.sort_values(by="publications",ascending=False)[:20]

# %%
top_20_country_df
# Out:
#                    country                                     institution  \
# 513                Ireland        National University of Ireland, Maynooth
# 1208        United Kingdom        University of Wales, Trinity Saint David
# 1333                 Japan                              Ibaraki University
# 658            Puerto Rico           University of Puerto Rico at Mayagüez
# 443                 France                University of Évry Val d'Essonne
# 1325           Puerto Rico           University of Puerto Rico at Mayagüez
# 651            South Korea                             University of Seoul
# 1360                 Egypt                           Alexandria University
# 1142                France                University of Évry Val d'Essonne
# 980                 France                            École Centrale Paris
# 273                 France                            École Centrale Paris
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_20_country_df["country"],y=top_20_country_df['publications'])
plt.show()

# %%
top_20_country_df.groupby("country")['publications'].mean().sort_values(ascending=False)
# Out:
# country
# United Kingdom          1000.00
# Puerto Rico              998.50
# Egypt                    997.00
# Ireland                  996.00
# France                   994.80
# Japan                    994.25
# United Arab Emirates     994.00
# South Korea              993.00
# Czech Republic           992.50
# Name: publications, dtype: float64

# %% [markdown]
# # Comparing Top 10 Country and instituions Based on scores

# %%
top_10_country_df=df[['country','institution','score']]

# %%
top_10_country_df=top_10_country_df.reset_index(drop=True)

# %%
top_10_country_df=top_10_country_df.sort_values(by="score",ascending=False)[:10]

# %%
top_10_country_df
# Out:
#        country                      institution  score
# 0          USA                 Emory University  53.01
# 1          USA  Georgia Institute of Technology  52.74
# 2        China              Tsinghua University  52.60
# 682      Japan                Tohoku University  52.57
# 683      China              Tsinghua University  52.21
# 684        USA  Georgia Institute of Technology  52.08
# 685    Belgium   Katholieke Universiteit Leuven  52.03
# 3        Japan                Kyushu University  51.96
# 4      Belgium   Katholieke Universiteit Leuven  51.72
# 5    Australia          University of Melbourne  51.43

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_10_country_df["country"],y=top_10_country_df['score'])
plt.show()

# %%
top_10_country_df.groupby("country")['score'].mean().sort_values(ascending=False)
# Out:
# country
# USA          52.610
# China        52.405
# Japan        52.265
# Belgium      51.875
# Australia    51.430
# Name: score, dtype: float64

# %% [markdown]
# # Comparing  Country and instituions Based on citations

# %%
top_country_scores_df=df[['country','institution','citations']]

# %%
top_country_scores_df=top_country_scores_df.reset_index(drop=True)

# %%
top_country_scores_df=top_country_scores_df.sort_values(by="citations",ascending=False)

# %%
top_country_scores_df
# Out:
#              country                          institution  citations
# 1363           China      China Pharmaceutical University        812
# 1026        Malaysia           Putra University, Malaysia        812
# 1108  United Kingdom               Heriot-Watt University        812
# 1102          Israel                  University of Haifa        812
# 1101          France  University François Rabelais, Tours        812
# ...              ...                                  ...        ...
# 42               USA             University of New Mexico         61
# 703              USA        University of Texas at Dallas         59
# 685          Belgium       Katholieke Universiteit Leuven         53
# 686        Australia              University of Melbourne         53
# 7                USA            Michigan State University         45
#
# [1364 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_country_scores_df["country"],y=top_country_scores_df['citations'])
plt.xticks(rotation=90)
plt.show()

# %%
top_country_scores_df=top_country_scores_df.groupby("country")['citations'].mean().sort_values(ascending=False)

# %%
top_country_scores_df
# Out:
# country
# Lebanon                 806.000000
# United Arab Emirates    806.000000
# Uruguay                 806.000000
# Saudi Arabia            718.500000
# Taiwan                  698.204545
# Romania                 688.666667
# Iran                    681.687500
# China                   642.012121
# Egypt                   636.500000
# Hungary                 634.111111
# Uganda                  627.000000
# Cyprus                  627.000000
# Puerto Rico             627.000000
# Lithuania               627.000000
# Israel                  620.600000
# Brazil                  608.000000
# Poland                  599.812500
# Austria                 599.388889
# India                   599.096774
# South Korea             598.161765
# Malaysia                595.000000
# Argentina               594.200000
# Chile                   593.625000
# Portugal                589.000000
# Russia                  587.200000
# Czech Republic          581.222222
# ...

# %%
#broad_impact

# %% [markdown]
# # Comparing  Country and instituions Based on broad_impact

# %%
top_country_broad_impact_df=df[['country','institution','broad_impact']]

# %%
top_country_broad_impact_df=top_country_broad_impact_df.reset_index(drop=True)

# %%
top_country_broad_impact_df=top_country_broad_impact_df.sort_values(by="broad_impact",ascending=False)

# %%
top_country_broad_impact_df
# Out:
#            country                                institution  broad_impact
# 681          China                         Yanbian University        1000.0
# 680          China  National University of Defense Technology         999.0
# 1338         China                        Shenzhen University         999.0
# 1356         China              Southwest Jiaotong University         998.0
# 673   Saudi Arabia                  King Abdulaziz University         998.0
# ...            ...                                        ...           ...
# 685        Belgium             Katholieke Universiteit Leuven          46.0
# 694            USA                 Baylor College of Medicine          44.0
# 19             USA              University of Texas at Dallas          44.0
# 10             USA                 Baylor College of Medicine          41.0
# 0              USA                           Emory University          37.0
#
# [1364 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_country_broad_impact_df["country"],y=top_country_broad_impact_df['broad_impact'])
plt.xticks(rotation=90)
plt.show()

# %%
top_country_broad_impact_df=top_country_broad_impact_df.groupby("country")['broad_impact'].mean().sort_values(ascending=False)

# %%
top_country_broad_impact_df
# Out:
# country
# Romania                 956.666667
# Egypt                   947.833333
# Saudi Arabia            946.666667
# Puerto Rico             938.500000
# Colombia                924.750000
# Cyprus                  904.500000
# United Arab Emirates    901.500000
# Iran                    865.625000
# Lebanon                 864.500000
# Malaysia                851.000000
# Uruguay                 849.000000
# Russia                  833.200000
# Uganda                  820.500000
# Argentina               818.000000
# Bulgaria                807.500000
# Poland                  799.750000
# Serbia                  757.500000
# Taiwan                  748.159091
# Lithuania               742.000000
# Brazil                  736.500000
# Turkey                  729.450000
# China                   714.393939
# India                   711.903226
# Czech Republic          678.666667
# Hungary                 676.777778
# South Korea             646.426471
# ...

# %% [markdown]
# # Comparing  Country and instituions Based on patients

# %%
country_patents_df=df[['country','institution','patents']]

# %%
country_patents_df=country_patents_df.reset_index(drop=True)

# %%
country_patents_df=country_patents_df.sort_values(by="patents",ascending=False)

# %%
country_patents_df
# Out:
#           country                                        institution  patents
# 1342       Taiwan                                 Yuan Ze University      871
# 1099         Iran                    Sharif University of Technology      871
# 1126        Japan                                Kitasato University      871
# 1122        Japan           Kyoto Prefectural University of Medicine      871
# 1120       Turkey                                  Ankara University      871
# ...           ...                                                ...      ...
# 682         Japan                                  Tohoku University       22
# 2           China                                Tsinghua University       16
# 6     South Korea                                  Yonsei University       15
# 12    South Korea  Korea Advanced Institute of Science and Techno...       11
# 706   South Korea  Korea Advanced Institute of Science and Techno...        8
#
# [1364 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=country_patents_df["country"],y=country_patents_df['patents'])
plt.xticks(rotation=90)
plt.show()

# %%
country_patents_df=country_patents_df.groupby("country")['patents'].mean().sort_values(ascending=False)

# %%
country_patents_df
# Out:
# country
# Romania                 826.333333
# Russia                  806.400000
# Lebanon                 804.000000
# Egypt                   804.000000
# Uganda                  804.000000
# Sweden                  804.000000
# Slovak Republic         804.000000
# Puerto Rico             804.000000
# Iran                    804.000000
# Uruguay                 804.000000
# Bulgaria                804.000000
# Thailand                802.333333
# Turkey                  795.050000
# Argentina               790.600000
# Iceland                 788.000000
# Serbia                  780.500000
# Cyprus                  776.500000
# Greece                  765.428571
# Colombia                746.000000
# Taiwan                  745.613636
# Lithuania               710.500000
# Norway                  708.714286
# Poland                  663.750000
# Italy                   661.493827
# Czech Republic          652.111111
# Brazil                  639.111111
# ...

# %%
#quality_of_education

# %% [markdown]
# # Comparing  Country and instituions Based on quality_of_education

# %%
quality_of_education_df=df[['country','institution','quality_of_education']]

# %%
quality_of_education_df=quality_of_education_df.reset_index(drop=True)

# %%
quality_of_education_df=quality_of_education_df.sort_values(by="quality_of_education",ascending=False)

# %%
quality_of_education_df
# Out:
#       country                         institution  quality_of_education
# 1363    China     China Pharmaceutical University                   367
# 969   Germany                University of Bremen                   367
# 951     Japan            Yokohama City University                   367
# 952     China                  Lanzhou University                   367
# 953    Greece                 University of Crete                   367
# ...       ...                                 ...                   ...
# 133   Germany  Darmstadt University of Technology                    55
# 172     China           Beijing Normal University                    51
# 873    Russia   Saint Petersburg State University                    47
# 682     Japan                   Tohoku University                    41
# 107    Russia   Saint Petersburg State University                    37
#
# [1364 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=quality_of_education_df["country"],y=quality_of_education_df['quality_of_education'])
plt.xticks(rotation=90)
plt.show()

# %%
quality_of_education_df=quality_of_education_df.groupby("country")['quality_of_education'].mean().sort_values(ascending=False)

# %%
quality_of_education_df
# Out:
# country
# Uruguay                 361.000000
# Iceland                 361.000000
# United Arab Emirates    361.000000
# Uganda                  361.000000
# Thailand                361.000000
# South Africa            361.000000
# Slovenia                361.000000
# Slovak Republic         361.000000
# Singapore               361.000000
# Colombia                361.000000
# Croatia                 361.000000
# Cyprus                  361.000000
# Saudi Arabia            361.000000
# Puerto Rico             361.000000
# Malaysia                361.000000
# Argentina               359.800000
# Austria                 359.555556
# Portugal                359.500000
# Estonia                 359.000000
# Denmark                 359.000000
# South Korea             357.676471
# Czech Republic          354.000000
# Italy                   351.716049
# Canada                  350.792453
# Spain                   350.395062
# Turkey                  350.300000
# ...

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %% [markdown]
# # Comparing  Country and instituions Based on quality_of_faculty

# %%
quality_of_faculty_df=df[['country','institution','quality_of_faculty']]

# %%
quality_of_faculty_df=quality_of_faculty_df.reset_index(drop=True)

# %%
quality_of_faculty_df=quality_of_faculty_df.sort_values(by="quality_of_faculty",ascending=False)

# %%
quality_of_faculty_df
# Out:
#             country                       institution  quality_of_faculty
# 682           Japan                 Tohoku University                 218
# 923          France            University of Rennes 1                 218
# 921           Japan                  Nihon University                 218
# 920  United Kingdom                 Brunel University                 218
# 919          Turkey  Middle East Technical University                 218
# ..              ...                               ...                 ...
# 116         Germany                Leipzig University                 201
# 736         Germany             University of Cologne                 201
# 726         Ireland           Trinity College, Dublin                 200
# 53   United Kingdom           University of Liverpool                 200
# 789  United Kingdom            University of Aberdeen                 199
#
# [1364 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=quality_of_faculty_df["country"],y=quality_of_faculty_df['quality_of_faculty'])
plt.xticks(rotation=90)
plt.show()

# %%
quality_of_faculty_df=quality_of_faculty_df.groupby("country")['quality_of_faculty'].mean().sort_values(ascending=False)

# %%
quality_of_faculty_df
# Out:
# country
# Romania                 215.333333
# Russia                  214.800000
# Israel                  214.800000
# South Korea             214.117647
# Canada                  214.075472
# Japan                   214.065574
# Australia               214.000000
# Lithuania               214.000000
# Malaysia                214.000000
# Mexico                  214.000000
# New Zealand             214.000000
# Poland                  214.000000
# Portugal                214.000000
# Puerto Rico             214.000000
# Lebanon                 214.000000
# Saudi Arabia            214.000000
# Singapore               214.000000
# Slovak Republic         214.000000
# Slovenia                214.000000
# South Africa            214.000000
# Sweden                  214.000000
# Thailand                214.000000
# Turkey                  214.000000
# Uganda                  214.000000
# United Arab Emirates    214.000000
# Serbia                  214.000000
# ...

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %%
country_score_year_df=df[['institution','country','year','score']]

# %%
country_score_year_df
# Out:
#                           institution   country  year  score
# 277                  Emory University       USA  2014  53.01
# 282   Georgia Institute of Technology       USA  2014  52.74
# 286               Tsinghua University     China  2014  52.60
# 291                 Kyushu University     Japan  2014  51.96
# 293    Katholieke Universiteit Leuven   Belgium  2014  51.72
# ...                               ...       ...   ...    ...
# 2195        University of the Algarve  Portugal  2015  44.03
# 2196            Alexandria University     Egypt  2015  44.03
# 2197      Federal University of Ceará    Brazil  2015  44.03
# 2198           University of A Coruña     Spain  2015  44.02
# 2199  China Pharmaceutical University     China  2015  44.02
#
# [1364 rows x 4 columns]

# %%
country_score_year_df=country_score_year_df.reset_index(drop=True)

# %%
country_score_year_df
# Out:
#                           institution   country  year  score
# 0                    Emory University       USA  2014  53.01
# 1     Georgia Institute of Technology       USA  2014  52.74
# 2                 Tsinghua University     China  2014  52.60
# 3                   Kyushu University     Japan  2014  51.96
# 4      Katholieke Universiteit Leuven   Belgium  2014  51.72
# ...                               ...       ...   ...    ...
# 1359        University of the Algarve  Portugal  2015  44.03
# 1360            Alexandria University     Egypt  2015  44.03
# 1361      Federal University of Ceará    Brazil  2015  44.03
# 1362           University of A Coruña     Spain  2015  44.02
# 1363  China Pharmaceutical University     China  2015  44.02
#
# [1364 rows x 4 columns]

# %%
country_score_year_df=country_score_year_df.sort_values(by="score",ascending=False).reset_index(drop=True)

# %%
country_score_year_df
# Out:
#                           institution   country  year  score
# 0                    Emory University       USA  2014  53.01
# 1     Georgia Institute of Technology       USA  2014  52.74
# 2                 Tsinghua University     China  2014  52.60
# 3                   Tohoku University     Japan  2015  52.57
# 4                 Tsinghua University     China  2015  52.21
# ...                               ...       ...   ...    ...
# 1359        University of the Algarve  Portugal  2015  44.03
# 1360            Alexandria University     Egypt  2015  44.03
# 1361      Federal University of Ceará    Brazil  2015  44.03
# 1362           University of A Coruña     Spain  2015  44.02
# 1363  China Pharmaceutical University     China  2015  44.02
#
# [1364 rows x 4 columns]

# %% [markdown]
# # Compare the score of country in the year 2015

# %%
country_score_year_2015_df=country_score_year_df[country_score_year_df['year']==2015]

# %%
country_score_year_2015_df
# Out:
#                           institution    country  year  score
# 3                   Tohoku University      Japan  2015  52.57
# 4                 Tsinghua University      China  2015  52.21
# 5     Georgia Institute of Technology        USA  2015  52.08
# 6      Katholieke Universiteit Leuven    Belgium  2015  52.03
# 10            University of Melbourne  Australia  2015  51.34
# ...                               ...        ...   ...    ...
# 1359        University of the Algarve   Portugal  2015  44.03
# 1360            Alexandria University      Egypt  2015  44.03
# 1361      Federal University of Ceará     Brazil  2015  44.03
# 1362           University of A Coruña      Spain  2015  44.02
# 1363  China Pharmaceutical University      China  2015  44.02
#
# [682 rows x 4 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=country_score_year_2015_df['country'],y=country_score_year_2015_df['score'])
plt.xticks(rotation=90)
plt.show()

# %%
country_score_year_2015_df.groupby("country")['score'].mean().sort_values(ascending=False)
# Out:
# country
# Singapore               49.290000
# USA                     47.653333
# Netherlands             47.362857
# Belgium                 46.171667
# Denmark                 46.036667
# Switzerland             46.022500
# Hong Kong               45.830000
# Canada                  45.459630
# South Korea             45.338000
# United Kingdom          45.315532
# Sweden                  45.266000
# Australia               45.210870
# Germany                 45.195135
# Ireland                 45.116250
# South Africa            45.053333
# Norway                  45.046667
# Italy                   44.982250
# New Zealand             44.925000
# Mexico                  44.920000
# Thailand                44.920000
# Iceland                 44.910000
# Finland                 44.875000
# Israel                  44.853333
# Spain                   44.845000
# France                  44.826944
# Austria                 44.791111
# China                   44.760000
# ...

# %% [markdown]
# # Compare patents of the country in the year 2015

# %%
df
# Out:
#       world_rank                      institution   country  national_rank  \
# 277           78                 Emory University       USA             49
# 282           83  Georgia Institute of Technology       USA             52
# 286           87              Tsinghua University     China              2
# 291           92                Kyushu University     Japan              7
# 293           94   Katholieke Universiteit Leuven   Belgium              1
# ...          ...                              ...       ...            ...
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %%
year_2015_df=df[df['year']==2015]

# %%
year_2015_df
# Out:
#       world_rank                      institution    country  national_rank  \
# 1272          73                Tohoku University      Japan              6
# 1277          78              Tsinghua University      China              2
# 1279          80  Georgia Institute of Technology        USA             48
# 1281          82   Katholieke Universiteit Leuven    Belgium              1
# 1292          93          University of Melbourne  Australia              2
# ...          ...                              ...        ...            ...
# 2195         996        University of the Algarve   Portugal              7
# 2196         997            Alexandria University      Egypt              4
# 2197         998      Federal University of Ceará     Brazil             18
# 2198         999           University of A Coruña      Spain             40
# 2199        1000  China Pharmaceutical University      China             83
#
# ...

# %%
label_df=year_2015_df.groupby("country")['patents'].mean().sort_values(ascending=False).index

# %%
value_df=year_2015_df.groupby("country")['patents'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
year_2015_df.groupby("country")['patents'].mean().sort_values(ascending=False)
# Out:
# country
# Argentina               871.000000
# Egypt                   871.000000
# Uganda                  871.000000
# Sweden                  871.000000
# Slovak Republic         871.000000
# Romania                 871.000000
# Puerto Rico             871.000000
# Iran                    871.000000
# Lebanon                 871.000000
# Uruguay                 871.000000
# Bulgaria                871.000000
# Thailand                867.666667
# Turkey                  863.100000
# Russia                  852.666667
# Iceland                 839.000000
# Greece                  834.571429
# Norway                  825.666667
# Serbia                  824.000000
# Cyprus                  816.000000
# Taiwan                  810.200000
# Colombia                805.000000
# Italy                   696.425000
# Poland                  691.875000
# United Arab Emirates    689.000000
# Lithuania               684.000000
# Brazil                  678.277778
# ...

# %% [markdown]
# # Compare the citations of country in the year 2015

# %%
label_df=year_2015_df.groupby("country")['citations'].mean().sort_values(ascending=False).index

# %%
value_df=year_2015_df.groupby("country")['citations'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
year_2015_df.groupby("country")['citations'].mean().sort_values(ascending=False)
# Out:
# country
# Lebanon                 812.000000
# United Arab Emirates    812.000000
# Uruguay                 812.000000
# Romania                 728.500000
# Iran                    711.750000
# Saudi Arabia            700.666667
# Taiwan                  680.000000
# Lithuania               645.000000
# Bulgaria                645.000000
# Slovak Republic         645.000000
# Uganda                  645.000000
# Cyprus                  645.000000
# Puerto Rico             645.000000
# Hungary                 641.600000
# China                   630.256098
# Israel                  628.333333
# Colombia                620.000000
# Brazil                  619.833333
# India                   618.687500
# Chile                   617.500000
# South Korea             606.857143
# Egypt                   600.333333
# Czech Republic          599.000000
# Finland                 594.875000
# Austria                 589.444444
# Japan                   584.709677
# ...

# %% [markdown]
# # Compare the publications of country in the year 2015

# %%
label_df=year_2015_df.groupby("country")['publications'].mean().sort_values(ascending=False).index

# %%
value_df=year_2015_df.groupby("country")['publications'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
year_2015_df.groupby("country")['publications'].mean().sort_values(ascending=False)
# Out:
# country
# Puerto Rico             998.000000
# United Arab Emirates    994.000000
# Egypt                   953.000000
# Lebanon                 915.000000
# Colombia                884.500000
# Uganda                  882.000000
# Romania                 859.500000
# Cyprus                  820.000000
# Uruguay                 814.000000
# Bulgaria                814.000000
# Russia                  799.000000
# Lithuania               799.000000
# Czech Republic          762.000000
# Hungary                 739.200000
# Japan                   738.435484
# Turkey                  734.700000
# Poland                  719.500000
# Iran                    712.125000
# Slovak Republic         707.000000
# Malaysia                700.333333
# Saudi Arabia            696.333333
# India                   686.625000
# Ireland                 645.750000
# Thailand                635.666667
# Chile                   632.750000
# Argentina               631.500000
# ...

# %% [markdown]
# # Compare the country of alumni_employment in the year 2015

# %%
label_df=year_2015_df.groupby("country")['alumni_employment'].mean().sort_values(ascending=False).index

# %%
value_df=year_2015_df.groupby("country")['alumni_employment'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
year_2015_df.groupby("country")['alumni_employment'].mean().sort_values(ascending=False)
# Out:
# country
# Uruguay                 567.000000
# Croatia                 567.000000
# Iran                    567.000000
# Lithuania               567.000000
# Norway                  567.000000
# Estonia                 567.000000
# Portugal                567.000000
# Czech Republic          567.000000
# Iceland                 567.000000
# Cyprus                  567.000000
# Puerto Rico             567.000000
# Romania                 567.000000
# Serbia                  567.000000
# Singapore               567.000000
# Bulgaria                567.000000
# Slovak Republic         567.000000
# Slovenia                567.000000
# Uganda                  567.000000
# Hungary                 567.000000
# Egypt                   566.666667
# Mexico                  556.500000
# Italy                   540.750000
# Argentina               540.000000
# United Arab Emirates    521.000000
# France                  520.972222
# Greece                  514.571429
# ...

# %%
#national_rank

# %% [markdown]
# # Compare national_rank and world rank of country in the year 2015

# %%
year_2015_df
# Out:
#       world_rank                      institution    country  national_rank  \
# 1272          73                Tohoku University      Japan              6
# 1277          78              Tsinghua University      China              2
# 1279          80  Georgia Institute of Technology        USA             48
# 1281          82   Katholieke Universiteit Leuven    Belgium              1
# 1292          93          University of Melbourne  Australia              2
# ...          ...                              ...        ...            ...
# 2195         996        University of the Algarve   Portugal              7
# 2196         997            Alexandria University      Egypt              4
# 2197         998      Federal University of Ceará     Brazil             18
# 2198         999           University of A Coruña      Spain             40
# 2199        1000  China Pharmaceutical University      China             83
#
# ...

# %%
institution_rank_df=year_2015_df[['institution','country','national_rank','world_rank']]

# %%
institution_rank_df=institution_rank_df.reset_index(drop=True)

# %%
institution_rank_df
# Out:
#                          institution    country  national_rank  world_rank
# 0                  Tohoku University      Japan              6          73
# 1                Tsinghua University      China              2          78
# 2    Georgia Institute of Technology        USA             48          80
# 3     Katholieke Universiteit Leuven    Belgium              1          82
# 4            University of Melbourne  Australia              2          93
# ..                               ...        ...            ...         ...
# 677        University of the Algarve   Portugal              7         996
# 678            Alexandria University      Egypt              4         997
# 679      Federal University of Ceará     Brazil             18         998
# 680           University of A Coruña      Spain             40         999
# 681  China Pharmaceutical University      China             83        1000
#
# [682 rows x 4 columns]

# %%
institution_rank_df=institution_rank_df.sort_values(by="world_rank")

# %%
institution_rank_df
# Out:
#                          institution    country  national_rank  world_rank
# 0                  Tohoku University      Japan              6          73
# 1                Tsinghua University      China              2          78
# 2    Georgia Institute of Technology        USA             48          80
# 3     Katholieke Universiteit Leuven    Belgium              1          82
# 4            University of Melbourne  Australia              2          93
# ..                               ...        ...            ...         ...
# 677        University of the Algarve   Portugal              7         996
# 678            Alexandria University      Egypt              4         997
# 679      Federal University of Ceará     Brazil             18         998
# 680           University of A Coruña      Spain             40         999
# 681  China Pharmaceutical University      China             83        1000
#
# [682 rows x 4 columns]

# %%
institution_rank_df=institution_rank_df.head(10)

# %% [markdown]
# # Country with Top 10 world rank in the year 2015

# %%
institution_rank_df
# Out:
#                        institution      country  national_rank  world_rank
# 0                Tohoku University        Japan              6          73
# 1              Tsinghua University        China              2          78
# 2  Georgia Institute of Technology          USA             48          80
# 3   Katholieke Universiteit Leuven      Belgium              1          82
# 4          University of Melbourne    Australia              2          93
# 5                Yonsei University  South Korea              2          98
# 6                Kyushu University        Japan              7         100
# 7            Georgetown University          USA             59         113
# 8          University of Amsterdam  Netherlands              5         114
# 9                 Korea University  South Korea              3         115

# %%
sns.barplot(x=institution_rank_df['country'],y=institution_rank_df['world_rank'])
plt.xticks(rotation=90)
plt.show()

# %%
institution_rank_df=institution_rank_df.sort_values(by="national_rank")

# %%
institution_rank_df
# Out:
#                        institution      country  national_rank  world_rank
# 3   Katholieke Universiteit Leuven      Belgium              1          82
# 1              Tsinghua University        China              2          78
# 4          University of Melbourne    Australia              2          93
# 5                Yonsei University  South Korea              2          98
# 9                 Korea University  South Korea              3         115
# 8          University of Amsterdam  Netherlands              5         114
# 0                Tohoku University        Japan              6          73
# 6                Kyushu University        Japan              7         100
# 2  Georgia Institute of Technology          USA             48          80
# 7            Georgetown University          USA             59         113

# %%
rank_1_df=institution_rank_df[institution_rank_df['national_rank']==1]

# %% [markdown]
# # Country with national rank 1 in the year 2015

# %%
rank_1_df
# Out:
#                       institution  country  national_rank  world_rank
# 3  Katholieke Universiteit Leuven  Belgium              1          82

# %%
sns.barplot(x=institution_rank_df['country'],y=institution_rank_df['national_rank'])
plt.xticks(rotation=90)
plt.show()
